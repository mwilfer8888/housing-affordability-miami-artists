# %%
import pandas as pd

# %%
file_path = 'raw-data/fl-occupational-wages-agg.xlsx'
sheet_name = 'Miami-Ft. Laud-WPB'

# %%
wages = pd.read_excel(file_path, sheet_name=sheet_name)

# %%
wages
# Out:
#     2023 Florida Occupational Employment and Wages  \
# 0            Miami-Fort Lauderdale-West Palm Beach
# 1                                              NaN
# 2                                              NaN
# 3                                     Occupational
# 4                                             Code
# ..                                             ...
# 745                                            NaN
# 746                                            NaN
# 747                                            NaN
# 748                                            NaN
# 749                                            NaN
#
#                                             Unnamed: 1  Unnamed: 2  \
# 0                                                  NaN         NaN
# 1                                                  NaN         NaN
# 2                                                  NaN         NaN
# 3                                         Occupational        2023
# ...
